# %%
import torch 
import torch.nn as nn 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
from sklearn.metrics import classification_report

# %%
path_to_train='Train/'
path_to_valid = 'Valid/'
path_to_test='Test/'

# %%
X_train=np.load(path_to_train+"X_train.npy")
X_valid=np.load(path_to_valid+"X_valid.npy")

# %%
y_train_superclass=np.load(path_to_train+"y_train_superclass.npy")
y_valid_superclass=np.load(path_to_valid+"y_valid_superclass.npy")

# %%
batch_size = 128

# %%
X_train_tensor = torch.Tensor(X_train)
y_train_tensor = torch.LongTensor(y_train_superclass)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)

X_valid_tensor = torch.Tensor(X_valid)
y_valid_tensor = torch.LongTensor(y_valid_superclass)

valid_dataset = TensorDataset(X_valid_tensor, y_valid_tensor)
valid_loader = DataLoader(valid_dataset, batch_size = batch_size, shuffle = True)

# %%
X_test=np.load(path_to_test+"X_test.npy")
y_test=np.load(path_to_test+"y_test_superclass.npy")

# %%
def train(epoch,my_model, data_loader, optimizer, loss_function):
    losses=[]
    my_model.train()
    for batch_idx, (X_batch, y_batch) in enumerate(data_loader):
        optimizer.zero_grad()
        output = my_model(X_batch)
        loss = loss_function(output, y_batch)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(X_batch), len(data_loader.dataset),
                100. * batch_idx / len(data_loader), loss.item()))
        losses.append(loss.data.numpy())
    return np.mean(losses)

# %%
def test(my_model, data_loader, loss_function):
    accuracy_arr = []
    my_model.eval()
    test_loss = 0
    correct = 0
    for X_batch, y_batch in data_loader:
        output = my_model(X_batch)
        test_loss += loss_function(output, y_batch).data
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(y_batch.data.view_as(pred)).cpu().sum()

    test_loss /= len(data_loader)
    acc = correct / len(data_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
    return acc,test_loss

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

def print_confusion_matrix(model, X, y):
    model.eval()
    y_pred = model(torch.Tensor(X)).data.numpy().argmax(axis = 1)
    print(confusion_matrix(y, y_pred))
    accuracy = accuracy_score(y, y_pred)
    print(f"Accuracy = {accuracy}")
    return accuracy

# %%
def training(number_of_epoches, model, optimizer, loss_function, learning_rate, train_loader, valid_loader):
    loss_train=[]
    loss_valid=[]
    acc=[]
    best_accuracy, last_accuracy = 0, 0
    patience = 3
    trigger_times = 0 
    
    for epoch in range(number_of_epoches):
        loss_train.append(train(epoch + 1,model, train_loader, optimizer, loss_function))
        accuracy, current_loss = test(model, valid_loader, loss_function)
        acc.append(accuracy)
        loss_valid.append(current_loss)
        if accuracy < last_accuracy:
            trigger_times += 1
            if trigger_times > patience:
                break
        else:
            trigger_times = 0  
        if epoch ==int(number_of_epoches * 0.3):
            optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)    
        print("Trigger times", trigger_times) 
        
        if accuracy > best_accuracy:
            best_accuracy = accuracy
        last_accuracy = accuracy
        
    return loss_train, loss_valid, acc

# %%
del X_train
del X_valid

del y_train_superclass
del y_valid_superclass

del X_train_tensor
del y_train_tensor

del X_valid_tensor
del y_valid_tensor

# %%
PI = torch.from_numpy(np.array(np.pi))
from torch.nn import functional as F

# %%
input_shape = 1000

# %%
class SincNet(nn.Module):
    
    @staticmethod
    def to_mel(hz):
        return 2595 * np.log10(1 + hz / 700)

    @staticmethod
    def to_hz(mel):
        return 700 * (10 ** (mel / 2595) - 1)
    
    def __init__(self, input_shape, number_of_filters, filter_length, min_low_hz=80, min_band_hz=80):
        super().__init__()
        self.number_of_filters = number_of_filters
        self.filter_length = filter_length
        self.sample_rate = 100        
        self.min_low_hz = min_low_hz
        self.min_band_hz = min_band_hz
        
        # initialize filterbanks such that they are equally spaced in Mel scale
        low_hz = 30
        high_hz = self.sample_rate / 2 - (self.min_low_hz + self.min_band_hz)

        mel = np.linspace(self.to_mel(low_hz),
                          self.to_mel(high_hz),
                          self.number_of_filters + 1)
        hz = self.to_hz(mel)
        
        # filter lower frequency (out_channels, 1)
        self.low_hz_ = nn.Parameter(torch.Tensor(hz[:-1]).view(-1, 1))

        # filter frequency band (out_channels, 1)
        self.band_hz_ = nn.Parameter(torch.Tensor(np.diff(hz)).view(-1, 1))
           
        
        self.LeakyReLU = nn.LeakyReLU(0.01)
         
        
       
    def forward(self, x):
                        
        n = torch.arange(0, self.filter_length // 2.0).view(1, -1)     
        f_1 = self.min_low_hz  + torch.abs(self.low_hz_)       
        f_2 = torch.clamp(f_1 + self.min_band_hz + torch.abs(self.band_hz_),self.min_low_hz,self.sample_rate/2)
        band=(f_2-f_1)[:,0]        
        
        g_filter = 2 * f_2 * torch.sinc(2 * PI * f_2 * n) - 2 * f_1 *torch.sinc(2 * PI * f_1 * n)
        
        window = 0.54 - 0.46 * torch.cos(2* PI * n)/ self.filter_length  
        g_filter_w = g_filter * window 
        g_filter_center = 2*band.view(-1,1)
        g_filter_right= torch.flip(g_filter_w,dims=[1])        
        g_filter_w =torch.cat([g_filter_w,g_filter_center,g_filter_right],dim=1)        
        g_filter_w = g_filter_w / (2*band[:,None])        
        filters = (g_filter_w).view(self.number_of_filters, 1, self.filter_length)  
        
        results = F.conv1d(x, filters)
        results = self.LeakyReLU(results)    

                
        return results

# %%
class CNN_with_SincNet(nn.Module):
    def __init__(self, input_shape,n_outputs, number_of_filters, filter_length, kernel_size):
        super().__init__()
        self.models_list = []
        self.models_ = []
        
        for i in range(12):
            self.models_list.append(self.SincNet_layer(input_shape, NUMBER_OF_FILTERS, L))
            
            
        self.conv1D_1 = nn.Conv1d(in_channels = 12 * number_of_filters, out_channels = 64, kernel_size = kernel_size[0], padding = 2)
        self.bn_1 = nn.BatchNorm1d(64)
        self.leakyReLU_1 = nn.LeakyReLU(0.01)
        self.maxpool = nn.MaxPool1d(2)
        self.conv1D_2 = nn.Conv1d(in_channels = 64, out_channels = 64, kernel_size = kernel_size[1], padding = 2)
        self.bn_2 = nn.BatchNorm1d(64)        
        self.leakyReLU_2 = nn.LeakyReLU(0.01)
        self.maxpool2 = nn.MaxPool1d(2)
        self.conv1D_3 = nn.Conv1d(in_channels = 64, out_channels = 64, kernel_size = kernel_size[2], padding = 2)
        self.bn_3 = nn.BatchNorm1d(64)
        self.leakyReLU_3 = nn.LeakyReLU(0.01)
        self.maxpool3 = nn.MaxPool1d(2)        
        self.conv1D_4 = nn.Conv1d(in_channels = 64, out_channels = 64, kernel_size = kernel_size[3], padding = 2)
        self.bn_4 = nn.BatchNorm1d(64)
        self.leakyReLU_4 = nn.LeakyReLU(0.01)    
        self.maxpool4 = nn.MaxPool1d(2)
        self.conv1D_5 = nn.Conv1d(in_channels = 64, out_channels = 64, kernel_size = kernel_size[4], padding = 2)
        self.bn_5 = nn.BatchNorm1d(64)
        self.leakyReLU_5 = nn.LeakyReLU(0.01)
        self.maxpool5 = nn.MaxPool1d(2)
        self.adAvgPooling = nn.AdaptiveAvgPool1d(2)        
        self.fl = nn.Flatten()
        
        self.lin1 = nn.Linear(2 * 64, 128)
        self.bn_6 = nn.BatchNorm1d(128)
        self.drop1 = nn.Dropout(0.6)
        self.leakyReLU_6 = nn.LeakyReLU(0.01)        

        self.lin2 = nn.Linear(128, n_outputs)
        self.softmax = nn.Softmax(dim=1)

        
    def SincNet_layer(self, input_shape, number_of_filters,length):    
        return nn.Sequential(SincNet(input_shape, number_of_filters, length))

    def forward(self, x):
        outputs = []
        
        data = np.array(x)
        data = np.array(np.split(data,12,axis = 1))
        data = torch.tensor(data)
        
        
        for i in range(12):
            outputs.append(self.models_list[i](data[i]))
        
        output = outputs[0]
        for i in range(1,12):
            output = torch.cat((output,outputs[i]), axis = 1)
         
        output = self.conv1D_1(output)
        output = self.bn_1(output)
        output = self.leakyReLU_1(output)
        output = self.maxpool(output)
        output = self.conv1D_2(output)
        output = self.bn_2(output)
        output = self.leakyReLU_2(output)
        output = self.maxpool2(output)
        output = self.conv1D_3(output)
        output = self.bn_3(output)
        output = self.leakyReLU_3(output)
        output = self.maxpool3(output)
        output = self.conv1D_4(output)
        output = self.bn_4(output)
        output = self.leakyReLU_4(output)
        output = self.maxpool4(output)
        output = self.conv1D_5(output)
        output = self.bn_5(output)
        output = self.leakyReLU_5(output)
        output = self.maxpool5(output)
        output = self.adAvgPooling(output)
        output = self.fl(output)
        

        output = self.lin1(output)
        output = self.bn_6(output)
        output = self.drop1(output)
        output = self.leakyReLU_6(output)
        output = self.lin2(output)
        output = self.softmax(output)        
        
        
        return output

# %%
loss_function=nn.CrossEntropyLoss()

# %%
learning_rate = 0.001
learning_rate_2 = 0.0001

# %%
input_shape=1000

# %%
NUMBER_OF_FILTERS = 5
L = 23

# %%
model = CNN_with_SincNet(input_shape, 5, NUMBER_OF_FILTERS, L, [5,5,5,5,5])

# %%
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

# %%
loss_train, loss_valid, accuracy = training(30, model, optimizer, loss_function, learning_rate_2, train_loader, valid_loader)
# Out:
# Train Epoch: 1 [0/12069 (0%)]	Loss: 1.610997
# Train Epoch: 1 [1280/12069 (11%)]	Loss: 1.435321
# Train Epoch: 1 [2560/12069 (21%)]	Loss: 1.365836
# Train Epoch: 1 [3840/12069 (32%)]	Loss: 1.266364
# Train Epoch: 1 [5120/12069 (42%)]	Loss: 1.284053
# Train Epoch: 1 [6400/12069 (53%)]	Loss: 1.312670
# Train Epoch: 1 [7680/12069 (63%)]	Loss: 1.261853
# Train Epoch: 1 [8960/12069 (74%)]	Loss: 1.213193
# Train Epoch: 1 [10240/12069 (84%)]	Loss: 1.262248
# Train Epoch: 1 [11520/12069 (95%)]	Loss: 1.214138
#
# Test set: Average loss: 1.2279, Accuracy: 1764/2587 (68.19%)
#
# Trigger times 0
# Train Epoch: 2 [0/12069 (0%)]	Loss: 1.217867
# Train Epoch: 2 [1280/12069 (11%)]	Loss: 1.227623
# Train Epoch: 2 [2560/12069 (21%)]	Loss: 1.226743
# Train Epoch: 2 [3840/12069 (32%)]	Loss: 1.245870
# Train Epoch: 2 [5120/12069 (42%)]	Loss: 1.144640
# Train Epoch: 2 [6400/12069 (53%)]	Loss: 1.184842
# Train Epoch: 2 [7680/12069 (63%)]	Loss: 1.174711
# Train Epoch: 2 [8960/12069 (74%)]	Loss: 1.227083
# Train Epoch: 2 [10240/12069 (84%)]	Loss: 1.195703
# Train Epoch: 2 [11520/12069 (95%)]	Loss: 1.228715
#
# Test set: Average loss: 1.2228, Accuracy: 1757/2587 (67.92%)
#
# Trigger times 1
# Train Epoch: 3 [0/12069 (0%)]	Loss: 1.195007
# Train Epoch: 3 [1280/12069 (11%)]	Loss: 1.189662
# Train Epoch: 3 [2560/12069 (21%)]	Loss: 1.180409
# Train Epoch: 3 [3840/12069 (32%)]	Loss: 1.193713
# Train Epoch: 3 [5120/12069 (42%)]	Loss: 1.166957
# Train Epoch: 3 [6400/12069 (53%)]	Loss: 1.229095
# Train Epoch: 3 [7680/12069 (63%)]	Loss: 1.215124
# Train Epoch: 3 [8960/12069 (74%)]	Loss: 1.176531
# Train Epoch: 3 [10240/12069 (84%)]	Loss: 1.183150
# Train Epoch: 3 [11520/12069 (95%)]	Loss: 1.195465
#
# Test set: Average loss: 1.2138, Accuracy: 1802/2587 (69.66%)
#
# Trigger times 0
# Train Epoch: 4 [0/12069 (0%)]	Loss: 1.132270
# Train Epoch: 4 [1280/12069 (11%)]	Loss: 1.218390
# Train Epoch: 4 [2560/12069 (21%)]	Loss: 1.229056
# Train Epoch: 4 [3840/12069 (32%)]	Loss: 1.191138
# Train Epoch: 4 [5120/12069 (42%)]	Loss: 1.207401
# Train Epoch: 4 [6400/12069 (53%)]	Loss: 1.217148
# Train Epoch: 4 [7680/12069 (63%)]	Loss: 1.181829
# Train Epoch: 4 [8960/12069 (74%)]	Loss: 1.190547
# Train Epoch: 4 [10240/12069 (84%)]	Loss: 1.190061
# Train Epoch: 4 [11520/12069 (95%)]	Loss: 1.105822
#
# Test set: Average loss: 1.2068, Accuracy: 1789/2587 (69.15%)
#
# Trigger times 1
# Train Epoch: 5 [0/12069 (0%)]	Loss: 1.182503
# Train Epoch: 5 [1280/12069 (11%)]	Loss: 1.194536
# Train Epoch: 5 [2560/12069 (21%)]	Loss: 1.127696
# Train Epoch: 5 [3840/12069 (32%)]	Loss: 1.139907
# Train Epoch: 5 [5120/12069 (42%)]	Loss: 1.176559
# Train Epoch: 5 [6400/12069 (53%)]	Loss: 1.151345
# Train Epoch: 5 [7680/12069 (63%)]	Loss: 1.155900
# Train Epoch: 5 [8960/12069 (74%)]	Loss: 1.171425
# Train Epoch: 5 [10240/12069 (84%)]	Loss: 1.198479
# Train Epoch: 5 [11520/12069 (95%)]	Loss: 1.180800
#
# Test set: Average loss: 1.2021, Accuracy: 1808/2587 (69.89%)
#
# Trigger times 0
# Train Epoch: 6 [0/12069 (0%)]	Loss: 1.191768
# Train Epoch: 6 [1280/12069 (11%)]	Loss: 1.163562
# Train Epoch: 6 [2560/12069 (21%)]	Loss: 1.147457
# Train Epoch: 6 [3840/12069 (32%)]	Loss: 1.185440
# Train Epoch: 6 [5120/12069 (42%)]	Loss: 1.143485
# Train Epoch: 6 [6400/12069 (53%)]	Loss: 1.210378
# Train Epoch: 6 [7680/12069 (63%)]	Loss: 1.138544
# Train Epoch: 6 [8960/12069 (74%)]	Loss: 1.193716
# Train Epoch: 6 [10240/12069 (84%)]	Loss: 1.137941
# Train Epoch: 6 [11520/12069 (95%)]	Loss: 1.091758
#
# Test set: Average loss: 1.1864, Accuracy: 1864/2587 (72.05%)
#
# Trigger times 0
# Train Epoch: 7 [0/12069 (0%)]	Loss: 1.175269
# Train Epoch: 7 [1280/12069 (11%)]	Loss: 1.148013
# Train Epoch: 7 [2560/12069 (21%)]	Loss: 1.202561
# Train Epoch: 7 [3840/12069 (32%)]	Loss: 1.151841
# Train Epoch: 7 [5120/12069 (42%)]	Loss: 1.219993
# Train Epoch: 7 [6400/12069 (53%)]	Loss: 1.162304
# Train Epoch: 7 [7680/12069 (63%)]	Loss: 1.060776
# Train Epoch: 7 [8960/12069 (74%)]	Loss: 1.131177
# Train Epoch: 7 [10240/12069 (84%)]	Loss: 1.103495
# Train Epoch: 7 [11520/12069 (95%)]	Loss: 1.083711
#
# Test set: Average loss: 1.1765, Accuracy: 1867/2587 (72.17%)
#
# Trigger times 0
# Train Epoch: 8 [0/12069 (0%)]	Loss: 1.153327
# Train Epoch: 8 [1280/12069 (11%)]	Loss: 1.137962
# Train Epoch: 8 [2560/12069 (21%)]	Loss: 1.128862
# Train Epoch: 8 [3840/12069 (32%)]	Loss: 1.083481
# Train Epoch: 8 [5120/12069 (42%)]	Loss: 1.204628
# Train Epoch: 8 [6400/12069 (53%)]	Loss: 1.180824
# Train Epoch: 8 [7680/12069 (63%)]	Loss: 1.147920
# Train Epoch: 8 [8960/12069 (74%)]	Loss: 1.050265
# Train Epoch: 8 [10240/12069 (84%)]	Loss: 1.140633
# Train Epoch: 8 [11520/12069 (95%)]	Loss: 1.149049
#
# Test set: Average loss: 1.2091, Accuracy: 1775/2587 (68.61%)
#
# Trigger times 1
# Train Epoch: 9 [0/12069 (0%)]	Loss: 1.130540
# Train Epoch: 9 [1280/12069 (11%)]	Loss: 1.150546
# Train Epoch: 9 [2560/12069 (21%)]	Loss: 1.151577
# Train Epoch: 9 [3840/12069 (32%)]	Loss: 1.131277
# Train Epoch: 9 [5120/12069 (42%)]	Loss: 1.134741
# Train Epoch: 9 [6400/12069 (53%)]	Loss: 1.158580
# Train Epoch: 9 [7680/12069 (63%)]	Loss: 1.139429
# Train Epoch: 9 [8960/12069 (74%)]	Loss: 1.112729
# Train Epoch: 9 [10240/12069 (84%)]	Loss: 1.145782
# Train Epoch: 9 [11520/12069 (95%)]	Loss: 1.146116
#
# Test set: Average loss: 1.1737, Accuracy: 1865/2587 (72.09%)
#
# Trigger times 0
# Train Epoch: 10 [0/12069 (0%)]	Loss: 1.164514
# Train Epoch: 10 [1280/12069 (11%)]	Loss: 1.123542
# Train Epoch: 10 [2560/12069 (21%)]	Loss: 1.163830
# Train Epoch: 10 [3840/12069 (32%)]	Loss: 1.135868
# Train Epoch: 10 [5120/12069 (42%)]	Loss: 1.102808
# Train Epoch: 10 [6400/12069 (53%)]	Loss: 1.156771
# Train Epoch: 10 [7680/12069 (63%)]	Loss: 1.124415
# Train Epoch: 10 [8960/12069 (74%)]	Loss: 1.176821
# Train Epoch: 10 [10240/12069 (84%)]	Loss: 1.162285
# Train Epoch: 10 [11520/12069 (95%)]	Loss: 1.167475
#
# Test set: Average loss: 1.2005, Accuracy: 1820/2587 (70.35%)
#
# Trigger times 1
# Train Epoch: 11 [0/12069 (0%)]	Loss: 1.108804
# Train Epoch: 11 [1280/12069 (11%)]	Loss: 1.145599
# Train Epoch: 11 [2560/12069 (21%)]	Loss: 1.132286
# Train Epoch: 11 [3840/12069 (32%)]	Loss: 1.151828
# Train Epoch: 11 [5120/12069 (42%)]	Loss: 1.124103
# Train Epoch: 11 [6400/12069 (53%)]	Loss: 1.098298
# Train Epoch: 11 [7680/12069 (63%)]	Loss: 1.176464
# Train Epoch: 11 [8960/12069 (74%)]	Loss: 1.143885
# Train Epoch: 11 [10240/12069 (84%)]	Loss: 1.131471
# Train Epoch: 11 [11520/12069 (95%)]	Loss: 1.097033
#
# Test set: Average loss: 1.1553, Accuracy: 1933/2587 (74.72%)
#
# Trigger times 0
# Train Epoch: 12 [0/12069 (0%)]	Loss: 1.137512
# Train Epoch: 12 [1280/12069 (11%)]	Loss: 1.108245
# Train Epoch: 12 [2560/12069 (21%)]	Loss: 1.136239
# Train Epoch: 12 [3840/12069 (32%)]	Loss: 1.084857
# Train Epoch: 12 [5120/12069 (42%)]	Loss: 1.141220
# Train Epoch: 12 [6400/12069 (53%)]	Loss: 1.088258
# Train Epoch: 12 [7680/12069 (63%)]	Loss: 1.080518
# Train Epoch: 12 [8960/12069 (74%)]	Loss: 1.078615
# Train Epoch: 12 [10240/12069 (84%)]	Loss: 1.098350
# Train Epoch: 12 [11520/12069 (95%)]	Loss: 1.080925
#
# Test set: Average loss: 1.1557, Accuracy: 1935/2587 (74.80%)
#
# Trigger times 0
# Train Epoch: 13 [0/12069 (0%)]	Loss: 1.091938
# Train Epoch: 13 [1280/12069 (11%)]	Loss: 1.137736
# Train Epoch: 13 [2560/12069 (21%)]	Loss: 1.119516
# Train Epoch: 13 [3840/12069 (32%)]	Loss: 1.146396
# Train Epoch: 13 [5120/12069 (42%)]	Loss: 1.104351
# Train Epoch: 13 [6400/12069 (53%)]	Loss: 1.051766
# Train Epoch: 13 [7680/12069 (63%)]	Loss: 1.122764
# Train Epoch: 13 [8960/12069 (74%)]	Loss: 1.124774
# Train Epoch: 13 [10240/12069 (84%)]	Loss: 1.092819
# Train Epoch: 13 [11520/12069 (95%)]	Loss: 1.109001
#
# Test set: Average loss: 1.1501, Accuracy: 1947/2587 (75.26%)
#
# Trigger times 0
# Train Epoch: 14 [0/12069 (0%)]	Loss: 1.090042
# Train Epoch: 14 [1280/12069 (11%)]	Loss: 1.130722
# Train Epoch: 14 [2560/12069 (21%)]	Loss: 1.066503
# Train Epoch: 14 [3840/12069 (32%)]	Loss: 1.122488
# Train Epoch: 14 [5120/12069 (42%)]	Loss: 1.075493
# Train Epoch: 14 [6400/12069 (53%)]	Loss: 1.144862
# Train Epoch: 14 [7680/12069 (63%)]	Loss: 1.084230
# Train Epoch: 14 [8960/12069 (74%)]	Loss: 1.138146
# Train Epoch: 14 [10240/12069 (84%)]	Loss: 1.112199
# Train Epoch: 14 [11520/12069 (95%)]	Loss: 1.104201
#
# Test set: Average loss: 1.1492, Accuracy: 1952/2587 (75.45%)
#
# Trigger times 0
# Train Epoch: 15 [0/12069 (0%)]	Loss: 1.134199
# Train Epoch: 15 [1280/12069 (11%)]	Loss: 1.149330
# Train Epoch: 15 [2560/12069 (21%)]	Loss: 1.160343
# Train Epoch: 15 [3840/12069 (32%)]	Loss: 1.112494
# Train Epoch: 15 [5120/12069 (42%)]	Loss: 1.120888
# Train Epoch: 15 [6400/12069 (53%)]	Loss: 1.086297
# Train Epoch: 15 [7680/12069 (63%)]	Loss: 1.106884
# Train Epoch: 15 [8960/12069 (74%)]	Loss: 1.093299
# Train Epoch: 15 [10240/12069 (84%)]	Loss: 1.064053
# Train Epoch: 15 [11520/12069 (95%)]	Loss: 1.106951
#
# Test set: Average loss: 1.1512, Accuracy: 1945/2587 (75.18%)
#
# Trigger times 1
# Train Epoch: 16 [0/12069 (0%)]	Loss: 1.058732
# Train Epoch: 16 [1280/12069 (11%)]	Loss: 1.110057
# Train Epoch: 16 [2560/12069 (21%)]	Loss: 1.084499
# Train Epoch: 16 [3840/12069 (32%)]	Loss: 1.119214
# Train Epoch: 16 [5120/12069 (42%)]	Loss: 1.044380
# Train Epoch: 16 [6400/12069 (53%)]	Loss: 1.077491
# Train Epoch: 16 [7680/12069 (63%)]	Loss: 1.072300
# Train Epoch: 16 [8960/12069 (74%)]	Loss: 1.067887
# Train Epoch: 16 [10240/12069 (84%)]	Loss: 1.117410
# Train Epoch: 16 [11520/12069 (95%)]	Loss: 1.109266
#
# Test set: Average loss: 1.1490, Accuracy: 1943/2587 (75.11%)
#
# Trigger times 2
# Train Epoch: 17 [0/12069 (0%)]	Loss: 1.078591
# Train Epoch: 17 [1280/12069 (11%)]	Loss: 1.145015
# Train Epoch: 17 [2560/12069 (21%)]	Loss: 1.125342
# Train Epoch: 17 [3840/12069 (32%)]	Loss: 1.081732
# Train Epoch: 17 [5120/12069 (42%)]	Loss: 1.070296
# Train Epoch: 17 [6400/12069 (53%)]	Loss: 1.113017
# Train Epoch: 17 [7680/12069 (63%)]	Loss: 1.016049
# Train Epoch: 17 [8960/12069 (74%)]	Loss: 1.036090
# Train Epoch: 17 [10240/12069 (84%)]	Loss: 1.073046
# Train Epoch: 17 [11520/12069 (95%)]	Loss: 1.089669
#
# Test set: Average loss: 1.1429, Accuracy: 1949/2587 (75.34%)
#
# Trigger times 0
# Train Epoch: 18 [0/12069 (0%)]	Loss: 1.115454
# Train Epoch: 18 [1280/12069 (11%)]	Loss: 1.154755
# Train Epoch: 18 [2560/12069 (21%)]	Loss: 1.127794
# Train Epoch: 18 [3840/12069 (32%)]	Loss: 1.118418
# Train Epoch: 18 [5120/12069 (42%)]	Loss: 1.095955
# Train Epoch: 18 [6400/12069 (53%)]	Loss: 1.068079
# Train Epoch: 18 [7680/12069 (63%)]	Loss: 1.075053
# Train Epoch: 18 [8960/12069 (74%)]	Loss: 1.057999
# Train Epoch: 18 [10240/12069 (84%)]	Loss: 1.178182
# Train Epoch: 18 [11520/12069 (95%)]	Loss: 1.124903
#
# Test set: Average loss: 1.1452, Accuracy: 1955/2587 (75.57%)
#
# Trigger times 0
# Train Epoch: 19 [0/12069 (0%)]	Loss: 1.109493
# Train Epoch: 19 [1280/12069 (11%)]	Loss: 1.053398
# Train Epoch: 19 [2560/12069 (21%)]	Loss: 1.151173
# Train Epoch: 19 [3840/12069 (32%)]	Loss: 1.136111
# Train Epoch: 19 [5120/12069 (42%)]	Loss: 1.066367
# Train Epoch: 19 [6400/12069 (53%)]	Loss: 1.149294
# Train Epoch: 19 [7680/12069 (63%)]	Loss: 1.090026
# Train Epoch: 19 [8960/12069 (74%)]	Loss: 1.145109
# Train Epoch: 19 [10240/12069 (84%)]	Loss: 1.055125
# Train Epoch: 19 [11520/12069 (95%)]	Loss: 1.045328
#
# Test set: Average loss: 1.1443, Accuracy: 1970/2587 (76.15%)
#
# Trigger times 0
# Train Epoch: 20 [0/12069 (0%)]	Loss: 1.099584
# Train Epoch: 20 [1280/12069 (11%)]	Loss: 1.027403
# Train Epoch: 20 [2560/12069 (21%)]	Loss: 1.136075
# Train Epoch: 20 [3840/12069 (32%)]	Loss: 1.115595
# Train Epoch: 20 [5120/12069 (42%)]	Loss: 1.055503
# Train Epoch: 20 [6400/12069 (53%)]	Loss: 1.146934
# Train Epoch: 20 [7680/12069 (63%)]	Loss: 1.112110
# Train Epoch: 20 [8960/12069 (74%)]	Loss: 1.109523
# Train Epoch: 20 [10240/12069 (84%)]	Loss: 1.097077
# Train Epoch: 20 [11520/12069 (95%)]	Loss: 1.113027
#
# Test set: Average loss: 1.1416, Accuracy: 1955/2587 (75.57%)
#
# Trigger times 1
# Train Epoch: 21 [0/12069 (0%)]	Loss: 1.063735
# Train Epoch: 21 [1280/12069 (11%)]	Loss: 1.089956
# Train Epoch: 21 [2560/12069 (21%)]	Loss: 1.154756
# Train Epoch: 21 [3840/12069 (32%)]	Loss: 1.097436
# Train Epoch: 21 [5120/12069 (42%)]	Loss: 1.150788
# Train Epoch: 21 [6400/12069 (53%)]	Loss: 1.086164
# Train Epoch: 21 [7680/12069 (63%)]	Loss: 1.014857
# Train Epoch: 21 [8960/12069 (74%)]	Loss: 1.069798
# Train Epoch: 21 [10240/12069 (84%)]	Loss: 1.087877
# Train Epoch: 21 [11520/12069 (95%)]	Loss: 1.073961
#
# Test set: Average loss: 1.1422, Accuracy: 1953/2587 (75.49%)
#
# Trigger times 2
# Train Epoch: 22 [0/12069 (0%)]	Loss: 1.051309
# Train Epoch: 22 [1280/12069 (11%)]	Loss: 1.048703
# Train Epoch: 22 [2560/12069 (21%)]	Loss: 1.113917
# Train Epoch: 22 [3840/12069 (32%)]	Loss: 1.052224
# Train Epoch: 22 [5120/12069 (42%)]	Loss: 1.093635
# Train Epoch: 22 [6400/12069 (53%)]	Loss: 1.168615
# Train Epoch: 22 [7680/12069 (63%)]	Loss: 1.031800
# Train Epoch: 22 [8960/12069 (74%)]	Loss: 1.077476
# Train Epoch: 22 [10240/12069 (84%)]	Loss: 1.162350
# Train Epoch: 22 [11520/12069 (95%)]	Loss: 1.133174
#
# Test set: Average loss: 1.1480, Accuracy: 1940/2587 (74.99%)
#
# Trigger times 3
# Train Epoch: 23 [0/12069 (0%)]	Loss: 1.054453
# Train Epoch: 23 [1280/12069 (11%)]	Loss: 1.048466
# Train Epoch: 23 [2560/12069 (21%)]	Loss: 1.141801
# Train Epoch: 23 [3840/12069 (32%)]	Loss: 1.118447
# Train Epoch: 23 [5120/12069 (42%)]	Loss: 1.078073
# Train Epoch: 23 [6400/12069 (53%)]	Loss: 1.046338
# Train Epoch: 23 [7680/12069 (63%)]	Loss: 1.063506
# Train Epoch: 23 [8960/12069 (74%)]	Loss: 1.049627
# Train Epoch: 23 [10240/12069 (84%)]	Loss: 1.059520
# Train Epoch: 23 [11520/12069 (95%)]	Loss: 1.064606
#
# Test set: Average loss: 1.1427, Accuracy: 1952/2587 (75.45%)
#
# Trigger times 0
# Train Epoch: 24 [0/12069 (0%)]	Loss: 1.103177
# Train Epoch: 24 [1280/12069 (11%)]	Loss: 1.090705
# Train Epoch: 24 [2560/12069 (21%)]	Loss: 1.101066
# Train Epoch: 24 [3840/12069 (32%)]	Loss: 1.103838
# Train Epoch: 24 [5120/12069 (42%)]	Loss: 1.061997
# Train Epoch: 24 [6400/12069 (53%)]	Loss: 1.080437
# Train Epoch: 24 [7680/12069 (63%)]	Loss: 1.119235
# Train Epoch: 24 [8960/12069 (74%)]	Loss: 1.173345
# Train Epoch: 24 [10240/12069 (84%)]	Loss: 1.049565
# Train Epoch: 24 [11520/12069 (95%)]	Loss: 1.066377
#
# Test set: Average loss: 1.1434, Accuracy: 1962/2587 (75.84%)
#
# Trigger times 0
# Train Epoch: 25 [0/12069 (0%)]	Loss: 1.097904
# Train Epoch: 25 [1280/12069 (11%)]	Loss: 1.075824
# Train Epoch: 25 [2560/12069 (21%)]	Loss: 1.078471
# Train Epoch: 25 [3840/12069 (32%)]	Loss: 1.075672
# Train Epoch: 25 [5120/12069 (42%)]	Loss: 1.081427
# Train Epoch: 25 [6400/12069 (53%)]	Loss: 1.029832
# Train Epoch: 25 [7680/12069 (63%)]	Loss: 1.099155
# Train Epoch: 25 [8960/12069 (74%)]	Loss: 1.136675
# Train Epoch: 25 [10240/12069 (84%)]	Loss: 1.131298
# Train Epoch: 25 [11520/12069 (95%)]	Loss: 1.103121
#
# Test set: Average loss: 1.1453, Accuracy: 1952/2587 (75.45%)
#
# Trigger times 1
# Train Epoch: 26 [0/12069 (0%)]	Loss: 1.049967
# Train Epoch: 26 [1280/12069 (11%)]	Loss: 1.057922
# Train Epoch: 26 [2560/12069 (21%)]	Loss: 1.102362
# Train Epoch: 26 [3840/12069 (32%)]	Loss: 1.074045
# Train Epoch: 26 [5120/12069 (42%)]	Loss: 1.087126
# Train Epoch: 26 [6400/12069 (53%)]	Loss: 1.059123
# Train Epoch: 26 [7680/12069 (63%)]	Loss: 1.059058
# Train Epoch: 26 [8960/12069 (74%)]	Loss: 1.081896
# Train Epoch: 26 [10240/12069 (84%)]	Loss: 1.044706
# Train Epoch: 26 [11520/12069 (95%)]	Loss: 1.067079
#
# Test set: Average loss: 1.1480, Accuracy: 1948/2587 (75.30%)
#
# Trigger times 2
# Train Epoch: 27 [0/12069 (0%)]	Loss: 1.065999
# Train Epoch: 27 [1280/12069 (11%)]	Loss: 1.085670
# Train Epoch: 27 [2560/12069 (21%)]	Loss: 1.032678
# Train Epoch: 27 [3840/12069 (32%)]	Loss: 1.061405
# Train Epoch: 27 [5120/12069 (42%)]	Loss: 1.069145
# Train Epoch: 27 [6400/12069 (53%)]	Loss: 1.052799
# Train Epoch: 27 [7680/12069 (63%)]	Loss: 1.074345
# Train Epoch: 27 [8960/12069 (74%)]	Loss: 1.081089
# Train Epoch: 27 [10240/12069 (84%)]	Loss: 1.101804
# Train Epoch: 27 [11520/12069 (95%)]	Loss: 1.121621
#
# Test set: Average loss: 1.1483, Accuracy: 1953/2587 (75.49%)
#
# Trigger times 0
# Train Epoch: 28 [0/12069 (0%)]	Loss: 1.043650
# Train Epoch: 28 [1280/12069 (11%)]	Loss: 1.064653
# Train Epoch: 28 [2560/12069 (21%)]	Loss: 1.103510
# Train Epoch: 28 [3840/12069 (32%)]	Loss: 1.072110
# Train Epoch: 28 [5120/12069 (42%)]	Loss: 1.056344
# Train Epoch: 28 [6400/12069 (53%)]	Loss: 1.069551
# Train Epoch: 28 [7680/12069 (63%)]	Loss: 1.072226
# Train Epoch: 28 [8960/12069 (74%)]	Loss: 1.080133
# Train Epoch: 28 [10240/12069 (84%)]	Loss: 1.086135
# Train Epoch: 28 [11520/12069 (95%)]	Loss: 1.105433
#
# Test set: Average loss: 1.1490, Accuracy: 1966/2587 (76.00%)
#
# Trigger times 0
# Train Epoch: 29 [0/12069 (0%)]	Loss: 1.097958
# Train Epoch: 29 [1280/12069 (11%)]	Loss: 1.080279
# Train Epoch: 29 [2560/12069 (21%)]	Loss: 1.170668
# Train Epoch: 29 [3840/12069 (32%)]	Loss: 1.043471
# Train Epoch: 29 [5120/12069 (42%)]	Loss: 1.068791
# Train Epoch: 29 [6400/12069 (53%)]	Loss: 1.079114
# Train Epoch: 29 [7680/12069 (63%)]	Loss: 1.075843
# Train Epoch: 29 [8960/12069 (74%)]	Loss: 1.119858
# Train Epoch: 29 [10240/12069 (84%)]	Loss: 1.031439
# Train Epoch: 29 [11520/12069 (95%)]	Loss: 1.082425
#
# Test set: Average loss: 1.1441, Accuracy: 1965/2587 (75.96%)
#
# Trigger times 1
# Train Epoch: 30 [0/12069 (0%)]	Loss: 1.062541
# Train Epoch: 30 [1280/12069 (11%)]	Loss: 1.088919
# Train Epoch: 30 [2560/12069 (21%)]	Loss: 1.092216
# Train Epoch: 30 [3840/12069 (32%)]	Loss: 1.060038
# Train Epoch: 30 [5120/12069 (42%)]	Loss: 1.105212
# Train Epoch: 30 [6400/12069 (53%)]	Loss: 1.041983
# Train Epoch: 30 [7680/12069 (63%)]	Loss: 1.083822
# Train Epoch: 30 [8960/12069 (74%)]	Loss: 1.114400
# Train Epoch: 30 [10240/12069 (84%)]	Loss: 1.054096
# Train Epoch: 30 [11520/12069 (95%)]	Loss: 1.039610
#
# Test set: Average loss: 1.1413, Accuracy: 1957/2587 (75.65%)
#
# Trigger times 2

# %%
print_confusion_matrix(model, X_test, y_test)
# Out:
# [[300  74   7  43  28]
#  [ 41 352   1  45  55]
#  [ 10  10  48  34  12]
#  [ 45  27   9 335  62]
#  [ 12  38   6  63 929]]
# Accuracy = 0.7594740912606341
# 0.7594740912606341

# %%
plt.plot(loss_train, label = 'Train Loss')
plt.plot(loss_valid, label = 'Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(accuracy, label = 'accuracy')
plt.legend()
plt.show()

# %%
print("Best accuracy: ",np.max(accuracy)," Epoch: ", np.argmax(accuracy)+1)
# Out:
# Best accuracy:  0.7614998  Epoch:  19

# %%
model.eval()
y_pred = model(torch.Tensor(X_test)).data.numpy().argmax(axis = 1)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70       452
#            1       0.70      0.71      0.71       494
#            2       0.68      0.42      0.52       114
#            3       0.64      0.70      0.67       478
#            4       0.86      0.89      0.87      1048
#
#     accuracy                           0.76      2586
#    macro avg       0.72      0.68      0.69      2586
# weighted avg       0.76      0.76      0.76      2586

# %%
cm = confusion_matrix(y_test,y_pred)
f = sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', center = 0)
